# %%
from scipy.optimize import curve_fit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\0,006.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x_array = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x, dtype=float)

plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\0,019.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x, dtype=float)

plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\0,037.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x_array = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x_array, dtype=float)

plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\0,164.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x_array = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x_array, dtype=float)

plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\0,321.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x_array = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x_array, dtype=float)

plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\0,512.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x_array = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x_array, dtype=float)
dat = dat[::-1]
plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def gaussian(x, amplitude, center, sigma):
    return amplitude * np.exp(-((x - center) / sigma) ** 2 / 2)

def lorentzian(x, amplitude, center, gamma):
    return (amplitude * (gamma**2 / ((x - center)**2 + gamma**2)))

# Create combined model using lmfit
model = Model(gaussian) + Model(lorentzian)

# Fit the model to data
result = model.fit(residuals, x=x, amplitude=-0.1, center=0, sigma=1, gamma=0.1)  # Initial guesses

# Print fit report
print(result.fit_report())

# Plot the data and the fitted curves
plt.figure(figsize=(10, 6))
plt.plot(x_array, y_array, label='Data', linewidth=2)
plt.plot(x_array, result.best_fit, label='Fit', linestyle='dashed')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Fitted Lamb Dips')
plt.show()

# %%
def lorentzian(x, x0, gamma, A,offset):
    return A * (gamma**2 / ((x - x0)**2 + gamma**2))+offset

def fitgenerator(y_dat,xmin,xmax):
    steps=xmax-xmin
    x_data = np.linspace(-10, 10, steps)
    y_data=y_dat[xmin:xmax]
    # Fit the Lorentzian function to the data
    initial_guess = [0, 1, 1,0]  # Initial parameter guess [x0, gamma, A]
    optimized_parameters, covariance = curve_fit(lorentzian, x_data, y_data, p0=initial_guess)

    # Extract the optimized parameters
    x0_opt, gamma_opt, A_opt, offset_opt = optimized_parameters

    # Generate the fitted Lorentzian curve
    y_fit = lorentzian(x_data, x0_opt, gamma_opt, A_opt, offset_opt)

    # Plot the original data and the fitted curve
    plt.scatter(x_data, y_data, label='Data')
    plt.plot(x_data, y_fit, label='Fit')
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

    return(optimized_parameters,covariance,y_fit)

def parameters(x_arr,dat,xmin,xmax,increment,fitsize):
    
    covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
    params=fitgenerator(dat,xmin,xmax)[0]
    
    x0=params[0]
    stepsize=(10+10)/fitsize
    aa=(x0+10)/stepsize   
    print(aa) ###
    X_0=x_arr[xmin]+aa*increment       #### 
    
    size=np.abs(x_arr[xmin]-x_arr[xmax])
    
    x0er=covs[0][0]
    X_0er=(x0er/20)*size
    
    g0=params[1]
    g0=g0*2    
    G_0=(g0/20)*size
    
    g0er=covs[1][1]
    g0er=g0er*2
    G_0er=(g0er/20)*size
    
    param_list=[X_0,G_0,params[2],params[3]]
    err_list=[X_0er,G_0er,covs[2][2],covs[3][3]]
    
    return param_list,err_list

def maxfinder(data):
    halflength=int(data.size/2)
    firstmax=min(data[:halflength])
    secmax=min(data[halflength:])
    
    return firstmax,secmax

def linearfit(x,a,b):
    
    return a*x+b

# %%
leftmin=[]
rightmin=[]

xmin=1500
xmax=3600

# %%
plt.plot(x[222:255],residuals[222:255])

# %%
p1,er1=parameters(x, np.array(residuals),160,235,5,75)
print(p1)
print(er1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 67.90008476889753
# [339.5143598444876, 0.00023519654031974407, 0.0010464112854216001, 0.001950031329855767]
# [3.729313174576766e-06, 2.696761497657943e-05, 9.86231515860987e-05, 9.842345689290929e-05]

# %%
p1,er1=parameters(x, np.array(residuals),235,285,5,50)
print(p1)
print(er1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 51.49259926524327
# [257.47708232621636, 0.00016664525578859816, 0.0011791028746202942, 0.0025892115664841943]
# [3.3142586471940656e-06, 1.508315304148856e-05, 8.080526621178258e-05, 7.235693866603026e-05]

# %%
p1,er1=parameters(x, np.array(residuals),500,570,5,70)
print(p1)
print(er1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 75.72578083216744
# [378.6435201608372, 0.0003525970174721373, 0.003603575220343575, 0.00549369856719884]
# [3.741221306104271e-06, 2.571709979049723e-05, 0.0002553844962591442, 0.00024187515595761416]

# %%
p1,er1=parameters(x, np.array(residuals),570,611,5,41)
print(p1)
print(er1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 62.32965897099764
# [311.66305085498817, 0.00027661245399130584, 0.0031717767911526957, 0.007389117980550192]
# [1.971658610982693e-05, 7.0728994319158e-05, 0.0007489313400379945, 0.0005787166602307596]

# %%
plt.plot(x[600:695],residuals[600:695])

# %%
XList=[]
GList=[]
AList=[]
OffList=[]

# %%
#Doppler1
p1,er1=parameters(x, np.array(residuals),220,255,5,35)

X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
        
fitydatad1=fitgenerator(np.array(residuals),220,255)[2]
xd1=x[220:255]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 41.39917701257126

# %%
#Doppler2
p1,er1=parameters(x, np.array(residuals),380,450,5,70)
print(p1)
X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
print(er1)
fitydatad2=fitgenerator(np.array(residuals),380,450)[2]
xd2=x[380:450]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 111.87647455531267
# [559.3967487765633, 0.02575233185609323, 4.145607386618572, -4.139133646391433]
# [1.8653900335878258e-05, nan, nan, nan]

# %%
#Doppler3
p1,er1=parameters(x, np.array(residuals),560,580,5,20)
print(p1)
print(er1)
X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
fitydatad3=fitgenerator(np.array(residuals),560,580)[2]

xd3=x[560:580]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# -2.6826922301408924
# [-13.398725150704463, 9.728236583132343e-05, -0.0008162781706192239, 0.009783919207129182]
# [7.774328421877534e-06, 4.281043086336851e-05, 0.0003235841578685106, 0.0002954811280187115]

# %%
#Crossover1
p1,er1=parameters(x, np.array(residuals),600,625,5,25)
print(p1)
print(er1)
X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
fitydatac1=fitgenerator(np.array(residuals),600,625)[2]


xc1=x[600:625]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 36.8424812826835
# [184.2272224134175, 0.006625884462748876, 1.2772655467072354, -1.266644288186521]
# [9.174877492442568e-06, 0.495665788399141, 190.84515899444443, 190.84513808699535]

# %%
#Doppler4
p1,er1=parameters(x, np.array(residuals),640,660,5,45)
print(p1)
print(er1)
X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
fitydatad4=fitgenerator(np.array(residuals),640,660)[2]
xd4=x[640:660]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 50.73748931601499
# [253.70234258007494, 7.614945130228327e-05, 0.000671620334151417, 0.010613873875679018]
# [5.402937403382296e-06, 2.106266935018886e-05, 0.00014602469556473113, 0.00012125627350515652]

# %%
    #Doppler7
p1,er1=parameters(x, np.array(residuals),1550,1620,5,40)
print(p1)
print(er1)
X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
fitydatad7=fitgenerator(np.array(residuals),1550,1620)[2]
xd7=x[1550:1620]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 33.11170314939558
# [165.5752317469779, 0.00031081611680396467, -0.02218759562503345, -0.020789565898677875]
# [2.0040829383731762e-07, 3.6898710781901665e-06, 0.0003258645474721756, 0.000328287412775319]

# %%
#Doppler8
p1,er1=parameters(x, np.array(residuals),1810,1840,5,40)
print(p1)
print(er1)
X=str(round(p1[0],3)) +str(" \pm ")+ str(round(er1[0],3))
G=str(round(p1[1],3)) +str(" \pm ")+ str(round(er1[1],3))
A=str(p1[2]) +str(" \pm ")+ str(er1[2])
Off=str(p1[3]) +str(" \pm ")+ str(er1[3])
XList.append(X)
GList.append(G)
AList.append(A)
OffList.append(Off)
fitydatad8=fitgenerator(np.array(residuals),1810,1840)[2]
xd8=x[1810:1840]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11088\4102673473.py:30: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# -38.84102044252153
# [-194.18786621260767, 0.0003489246290108801, -0.025420159038459428, -0.0016735131962038545]
# [1.034221110044989e-05, 4.8977937988577166e-05, 0.0035707894622176487, 0.0030454099181052847]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df = pd.read_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\1.CSV')

y_array = df["DPO4104"][19:].to_numpy()
x_array = df["Model"][19:].to_numpy()

dat = np.array(y_array, dtype=float)
x = np.array(x_array, dtype=float)

plt.figure(figsize=(10, 6))

plt.plot(x, dat, label='Data', linewidth=2)

slope, intercept, r_value, p_value, std_err = linregress(x, dat)
fit_line = slope * x + intercept

plt.plot(x, fit_line, label='Fit', color='red', linestyle='dashed', linewidth=2)

plt.scatter(x, dat, label='Data Points', color='blue', marker='o', s=30, alpha=0.7)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit')
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.show()


residuals = dat - fit_line
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.axhline(y=0, color='red', linestyle='dashed')
#plt.xlabel('X')
#plt.ylabel('Residuals')
#plt.title('Residual Plot')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
dataa={'Rel_freq':x, 'Rel_power': np.array(residuals)}
dataframe = pd.DataFrame(data=dataa)
dataframe.to_csv('C:\\Users\\HP\\Desktop\\Bonn\\My Courses\\Advanced Lab Course\\A246 Laser Spectroscopy\\A246 Task 4 Data\\A246 Task 4 Data\\plotdata.CSV')

# %%
from lmfit.models import LorentzianModel, QuadraticModel

# %%
def add_peak(prefix, center, amplitude=0.005, sigma=0.05):
    peak = LorentzianModel(prefix=prefix)
    pars = peak.make_params()
    pars[prefix + 'center'].set(center)
    pars[prefix + 'amplitude'].set(amplitude)
    pars[prefix + 'sigma'].set(sigma, min=0)
    return peak, pars

# %%
model = QuadraticModel(prefix='bkg_')
params = model.make_params(a=0, b=0, c=0)

# %%
rough_peak_positions = (0.017, 0.022, 0.0223, 0.0226, 0.0271, 0.0274, 0.0277, 0.0289, 0.0296, 0.0302)
for i, cen in enumerate(rough_peak_positions):
    peak, pars = add_peak('lz%d_' % (i+1), cen)
    model = model + peak
    params.update(pars)

# %%
init = model.eval(params, x=x)
result = model.fit(residuals, params, x=x)
comps = result.eval_components()

print(result.fit_report(min_correl=0.5))

plt.plot(x, residuals, label='data')
plt.plot(x, result.best_fit, label='best fit')
for name, comp in comps.items():
    plt.plot(x, comp, '--', label=name)
plt.legend(loc='upper right')
plt.show()
# Out:
# [[Model]]
#     ((((((((((Model(parabolic, prefix='bkg_') + Model(lorentzian, prefix='lz1_')) + Model(lorentzian, prefix='lz2_')) + Model(lorentzian, prefix='lz3_')) + Model(lorentzian, prefix='lz4_')) + Model(lorentzian, prefix='lz5_')) + Model(lorentzian, prefix='lz6_')) + Model(lorentzian, prefix='lz7_')) + Model(lorentzian, prefix='lz8_')) + Model(lorentzian, prefix='lz9_')) + Model(lorentzian, prefix='lz10_'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 68000
#     # data points      = 10000
#     # variables        = 33
#     chi-square         = 0.29383170
#     reduced chi-square = 2.9480e-05
#     Akaike info crit   = -104284.885
#     Bayesian info crit = -104046.944
#     R-squared          = 0.91227689
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     bkg_a:          -1137.21089 (init = 0)
#     bkg_b:           67.9503922 (init = 0)
#     bkg_c:          -0.98923876 (init = 0)
# ...

# %%
threshold = 0  # Adjust this threshold based on your data
peaks = []
crossovers = []

for i in range(1, len(residuals) - 1):
    if residuals[i] > threshold and residuals[i] > residuals[i - 1] and residuals[i] > residuals[i + 1]:
        peaks.append(i)
    elif residuals[i] < -threshold and residuals[i] < residuals[i - 1] and residuals[i] < residuals[i + 1]:
        crossovers.append(i)

# Plot identified peaks and crossovers
plt.figure(figsize=(10, 6))
plt.plot(x, residuals, label='Residuals', color='blue', linewidth=2)
plt.scatter(x[peaks], residuals[peaks], color='green', marker='o', label='Peaks')
plt.scatter(x[crossovers], residuals[crossovers], color='red', marker='x', label='Crossovers')
plt.axhline(y=0, color='red', linestyle='dashed')
plt.xlabel('X')
plt.ylabel('Residuals')
plt.title('Residual Plot with Peaks and Crossovers')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from scipy.signal import find_peaks

# %%
def lorentzian(x, x0, gamma, A,offset):
    return A * (gamma**2 / ((x - x0)**2 + gamma**2))+offset

def fitgenerator(y_dat,xmin,xmax):
    steps=xmax-xmin
    x_data = np.linspace(-10, 10, steps)
    y_data=y_dat[xmin:xmax]
    # Fit the Lorentzian function to the data
    initial_guess = [0, 1, 1,0]  # Initial parameter guess [x0, gamma, A]
    optimized_parameters, covariance = curve_fit(lorentzian, x_data, y_data, p0=initial_guess)

    # Extract the optimized parameters
    x0_opt, gamma_opt, A_opt, offset_opt = optimized_parameters

    # Generate the fitted Lorentzian curve
    y_fit = lorentzian(x_data, x0_opt, gamma_opt, A_opt, offset_opt)

    # Plot the original data and the fitted curve
    plt.scatter(x_data, y_data, label='Data')
    plt.plot(x_data, y_fit, label='Fit')
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

    return(optimized_parameters,covariance,y_fit)

# %%
def parameters(x_arr,dat,xmin,xmax,increment,fitsize):
    
    covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
    params=fitgenerator(dat,xmin,xmax)[0]
    
    x0=params[0]
    stepsize=(10+10)/fitsize
    aa=(x0+10)/stepsize   
    print(x_arr[xmin]) ###
    X_0=x_arr[xmin]+aa*increment       #### 
    
    size=np.abs(x_arr[xmin]-x_arr[xmax])
    print(size)
    
    x0er=covs[0][0]
    X_0er=(x0er/20)*size
    
    g0=params[1]
    g0=g0*2    
    G_0=(g0/20)*size
    
    g0er=covs[1][1]
    g0er=g0er*2
    G_0er=(g0er/20)*size
    
    param_list=[X_0,G_0,params[2],params[3]]
    err_list=[X_0er,G_0er,covs[2][2],covs[3][3]]
    
    return param_list,err_list

# %%
p1,er1=parameters(x, np.array(residuals),500,570,5,70)
print(p1)
print(er1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10020\200038474.py:3: RuntimeWarning: invalid value encountered in sqrt
#   covs=np.sqrt(fitgenerator(dat,xmin,xmax)[1])
# 0.014616
# 0.0001399999999999995
# [-19.53785851935869, 0.0004055642546412053, -0.002145967668839086, -0.009264610926700839]
# [7.048463765633965e-06, 6.825263920698947e-05, 0.00039912233205309066, 0.00038886544566073565]
